# %%
# !pip install rapidfuzz scikit-learn joblib pyarrow
# Out:
# ...
#   Using cached scikit_learn-1.7.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# ...
#   Using cached joblib-1.6.0-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached pyarrow-25.0.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# ...
#   Using cached scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 101.7 MB/s  0:00:00
# Using cached scikit_learn-1.7.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
# Using cached joblib-1.6.0-py3-none-any.whl (306 kB)
# Using cached pyarrow-25.0.1-cp310-cp310-manylinux_2_28_x86_64.whl (50.1 MB)
# Using cached scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [scikit-learn] [scikit-learn]
# ...

# %%
# !df -h /
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# /dev/nvme0n1p1  105G   89G   17G  84% /

# %%
# %run stage5_name_features.py
# Out:
#                                    case_description  name_levenshtein_ratio  name_jaro_winkler  name_token_jaccard  name_tfidf_char3gram_cosine  \
# 0                                         identical                   1.000              1.000               1.000                        1.000
# 1                                      word reorder                   0.682              0.909               1.000                        1.000
# 2  abbreviation variant (not expanded upstream yet)                   0.846              0.947               0.333                        0.338
# 3                                              typo                   0.909              0.972               0.333                        0.466
# 4                                unrelated business                   0.293              0.479               0.000                        0.000
# ...
